# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(1 , figsize=(5,5))
x = np.linspace(-2,2,10000)
y = np.exp(-x**2)

plt.plot(x, y)

plt.xlabel('X')
plt.ylabel('Y')
plt.savefig('oña')

# %%
c = "Alondra"

# %%
c[::-1]
# Out:
# 'ardnolA'
